# %%
import os
import sys
from math import ceil, floor

# %%
# list files in the results directory
folder = "nc"
files = os.listdir(folder)
files
# Out:
# ['cbsstudy_individualDelays_il_10_s_1.txt',
#  'cbsstudy_individualDelays_il_10_s_10.txt',
#  'cbsstudy_individualDelays_il_10_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_11.txt',
#  'cbsstudy_individualDelays_il_10_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_12.txt',
#  'cbsstudy_individualDelays_il_10_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_13.txt',
#  'cbsstudy_individualDelays_il_10_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_14.txt',
#  'cbsstudy_individualDelays_il_10_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_15.txt',
#  'cbsstudy_individualDelays_il_10_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_16.txt',
#  'cbsstudy_individualDelays_il_10_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_17.txt',
#  'cbsstudy_individualDelays_il_10_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_18.txt',
#  'cbsstudy_individualDelays_il_10_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_19.txt',
#  'cbsstudy_individualDelays_il_10_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_2.txt',
#  'cbsstudy_individualDelays_il_10_s_20.txt',
#  'cbsstudy_individualDelays_il_10_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_3.txt',
#  'cbsstudy_individualDelays_il_10_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_4.txt',
#  'cbsstudy_individualDelays_il_10_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_5.txt',
#  'cbsstudy_individualDelays_il_10_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_6.txt',
#  'cbsstudy_individualDelays_il_10_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_7.txt',
#  'cbsstudy_individualDelays_il_10_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_8.txt',
#  'cbsstudy_individualDelays_il_10_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_10_s_9.txt',
#  'cbsstudy_individualDelays_il_10_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_1.txt',
#  'cbsstudy_individualDelays_il_11_s_10.txt',
#  'cbsstudy_individualDelays_il_11_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_11.txt',
#  'cbsstudy_individualDelays_il_11_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_12.txt',
#  'cbsstudy_individualDelays_il_11_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_13.txt',
#  'cbsstudy_individualDelays_il_11_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_14.txt',
#  'cbsstudy_individualDelays_il_11_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_15.txt',
#  'cbsstudy_individualDelays_il_11_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_16.txt',
#  'cbsstudy_individualDelays_il_11_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_17.txt',
#  'cbsstudy_individualDelays_il_11_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_18.txt',
#  'cbsstudy_individualDelays_il_11_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_19.txt',
#  'cbsstudy_individualDelays_il_11_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_2.txt',
#  'cbsstudy_individualDelays_il_11_s_20.txt',
#  'cbsstudy_individualDelays_il_11_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_3.txt',
#  'cbsstudy_individualDelays_il_11_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_4.txt',
#  'cbsstudy_individualDelays_il_11_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_5.txt',
#  'cbsstudy_individualDelays_il_11_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_6.txt',
#  'cbsstudy_individualDelays_il_11_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_7.txt',
#  'cbsstudy_individualDelays_il_11_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_8.txt',
#  'cbsstudy_individualDelays_il_11_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_11_s_9.txt',
#  'cbsstudy_individualDelays_il_11_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_1.txt',
#  'cbsstudy_individualDelays_il_12_s_10.txt',
#  'cbsstudy_individualDelays_il_12_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_11.txt',
#  'cbsstudy_individualDelays_il_12_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_12.txt',
#  'cbsstudy_individualDelays_il_12_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_13.txt',
#  'cbsstudy_individualDelays_il_12_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_14.txt',
#  'cbsstudy_individualDelays_il_12_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_15.txt',
#  'cbsstudy_individualDelays_il_12_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_16.txt',
#  'cbsstudy_individualDelays_il_12_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_17.txt',
#  'cbsstudy_individualDelays_il_12_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_18.txt',
#  'cbsstudy_individualDelays_il_12_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_19.txt',
#  'cbsstudy_individualDelays_il_12_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_2.txt',
#  'cbsstudy_individualDelays_il_12_s_20.txt',
#  'cbsstudy_individualDelays_il_12_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_3.txt',
#  'cbsstudy_individualDelays_il_12_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_4.txt',
#  'cbsstudy_individualDelays_il_12_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_5.txt',
#  'cbsstudy_individualDelays_il_12_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_6.txt',
#  'cbsstudy_individualDelays_il_12_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_7.txt',
#  'cbsstudy_individualDelays_il_12_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_8.txt',
#  'cbsstudy_individualDelays_il_12_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_12_s_9.txt',
#  'cbsstudy_individualDelays_il_12_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_1.txt',
#  'cbsstudy_individualDelays_il_13_s_10.txt',
#  'cbsstudy_individualDelays_il_13_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_11.txt',
#  'cbsstudy_individualDelays_il_13_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_12.txt',
#  'cbsstudy_individualDelays_il_13_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_13.txt',
#  'cbsstudy_individualDelays_il_13_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_14.txt',
#  'cbsstudy_individualDelays_il_13_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_15.txt',
#  'cbsstudy_individualDelays_il_13_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_16.txt',
#  'cbsstudy_individualDelays_il_13_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_17.txt',
#  'cbsstudy_individualDelays_il_13_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_18.txt',
#  'cbsstudy_individualDelays_il_13_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_19.txt',
#  'cbsstudy_individualDelays_il_13_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_2.txt',
#  'cbsstudy_individualDelays_il_13_s_20.txt',
#  'cbsstudy_individualDelays_il_13_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_3.txt',
#  'cbsstudy_individualDelays_il_13_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_4.txt',
#  'cbsstudy_individualDelays_il_13_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_5.txt',
#  'cbsstudy_individualDelays_il_13_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_6.txt',
#  'cbsstudy_individualDelays_il_13_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_7.txt',
#  'cbsstudy_individualDelays_il_13_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_8.txt',
#  'cbsstudy_individualDelays_il_13_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_13_s_9.txt',
#  'cbsstudy_individualDelays_il_13_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_1.txt',
#  'cbsstudy_individualDelays_il_2_s_10.txt',
#  'cbsstudy_individualDelays_il_2_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_11.txt',
#  'cbsstudy_individualDelays_il_2_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_12.txt',
#  'cbsstudy_individualDelays_il_2_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_13.txt',
#  'cbsstudy_individualDelays_il_2_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_14.txt',
#  'cbsstudy_individualDelays_il_2_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_15.txt',
#  'cbsstudy_individualDelays_il_2_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_16.txt',
#  'cbsstudy_individualDelays_il_2_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_17.txt',
#  'cbsstudy_individualDelays_il_2_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_18.txt',
#  'cbsstudy_individualDelays_il_2_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_19.txt',
#  'cbsstudy_individualDelays_il_2_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_2.txt',
#  'cbsstudy_individualDelays_il_2_s_20.txt',
#  'cbsstudy_individualDelays_il_2_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_3.txt',
#  'cbsstudy_individualDelays_il_2_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_4.txt',
#  'cbsstudy_individualDelays_il_2_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_5.txt',
#  'cbsstudy_individualDelays_il_2_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_6.txt',
#  'cbsstudy_individualDelays_il_2_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_7.txt',
#  'cbsstudy_individualDelays_il_2_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_8.txt',
#  'cbsstudy_individualDelays_il_2_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_2_s_9.txt',
#  'cbsstudy_individualDelays_il_2_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_1.txt',
#  'cbsstudy_individualDelays_il_3_s_10.txt',
#  'cbsstudy_individualDelays_il_3_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_11.txt',
#  'cbsstudy_individualDelays_il_3_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_12.txt',
#  'cbsstudy_individualDelays_il_3_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_13.txt',
#  'cbsstudy_individualDelays_il_3_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_14.txt',
#  'cbsstudy_individualDelays_il_3_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_15.txt',
#  'cbsstudy_individualDelays_il_3_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_16.txt',
#  'cbsstudy_individualDelays_il_3_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_17.txt',
#  'cbsstudy_individualDelays_il_3_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_18.txt',
#  'cbsstudy_individualDelays_il_3_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_19.txt',
#  'cbsstudy_individualDelays_il_3_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_2.txt',
#  'cbsstudy_individualDelays_il_3_s_20.txt',
#  'cbsstudy_individualDelays_il_3_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_3.txt',
#  'cbsstudy_individualDelays_il_3_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_4.txt',
#  'cbsstudy_individualDelays_il_3_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_5.txt',
#  'cbsstudy_individualDelays_il_3_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_6.txt',
#  'cbsstudy_individualDelays_il_3_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_7.txt',
#  'cbsstudy_individualDelays_il_3_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_8.txt',
#  'cbsstudy_individualDelays_il_3_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_3_s_9.txt',
#  'cbsstudy_individualDelays_il_3_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_1.txt',
#  'cbsstudy_individualDelays_il_4_s_10.txt',
#  'cbsstudy_individualDelays_il_4_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_11.txt',
#  'cbsstudy_individualDelays_il_4_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_12.txt',
#  'cbsstudy_individualDelays_il_4_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_13.txt',
#  'cbsstudy_individualDelays_il_4_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_14.txt',
#  'cbsstudy_individualDelays_il_4_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_15.txt',
#  'cbsstudy_individualDelays_il_4_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_16.txt',
#  'cbsstudy_individualDelays_il_4_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_17.txt',
#  'cbsstudy_individualDelays_il_4_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_18.txt',
#  'cbsstudy_individualDelays_il_4_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_19.txt',
#  'cbsstudy_individualDelays_il_4_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_2.txt',
#  'cbsstudy_individualDelays_il_4_s_20.txt',
#  'cbsstudy_individualDelays_il_4_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_3.txt',
#  'cbsstudy_individualDelays_il_4_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_4.txt',
#  'cbsstudy_individualDelays_il_4_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_5.txt',
#  'cbsstudy_individualDelays_il_4_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_6.txt',
#  'cbsstudy_individualDelays_il_4_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_7.txt',
#  'cbsstudy_individualDelays_il_4_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_8.txt',
#  'cbsstudy_individualDelays_il_4_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_4_s_9.txt',
#  'cbsstudy_individualDelays_il_4_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_1.txt',
#  'cbsstudy_individualDelays_il_5_s_10.txt',
#  'cbsstudy_individualDelays_il_5_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_11.txt',
#  'cbsstudy_individualDelays_il_5_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_12.txt',
#  'cbsstudy_individualDelays_il_5_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_13.txt',
#  'cbsstudy_individualDelays_il_5_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_14.txt',
#  'cbsstudy_individualDelays_il_5_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_15.txt',
#  'cbsstudy_individualDelays_il_5_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_16.txt',
#  'cbsstudy_individualDelays_il_5_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_17.txt',
#  'cbsstudy_individualDelays_il_5_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_18.txt',
#  'cbsstudy_individualDelays_il_5_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_19.txt',
#  'cbsstudy_individualDelays_il_5_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_2.txt',
#  'cbsstudy_individualDelays_il_5_s_20.txt',
#  'cbsstudy_individualDelays_il_5_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_3.txt',
#  'cbsstudy_individualDelays_il_5_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_4.txt',
#  'cbsstudy_individualDelays_il_5_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_5.txt',
#  'cbsstudy_individualDelays_il_5_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_6.txt',
#  'cbsstudy_individualDelays_il_5_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_7.txt',
#  'cbsstudy_individualDelays_il_5_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_8.txt',
#  'cbsstudy_individualDelays_il_5_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_5_s_9.txt',
#  'cbsstudy_individualDelays_il_5_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_1.txt',
#  'cbsstudy_individualDelays_il_6_s_10.txt',
#  'cbsstudy_individualDelays_il_6_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_11.txt',
#  'cbsstudy_individualDelays_il_6_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_12.txt',
#  'cbsstudy_individualDelays_il_6_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_13.txt',
#  'cbsstudy_individualDelays_il_6_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_14.txt',
#  'cbsstudy_individualDelays_il_6_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_15.txt',
#  'cbsstudy_individualDelays_il_6_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_16.txt',
#  'cbsstudy_individualDelays_il_6_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_17.txt',
#  'cbsstudy_individualDelays_il_6_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_18.txt',
#  'cbsstudy_individualDelays_il_6_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_19.txt',
#  'cbsstudy_individualDelays_il_6_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_2.txt',
#  'cbsstudy_individualDelays_il_6_s_20.txt',
#  'cbsstudy_individualDelays_il_6_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_3.txt',
#  'cbsstudy_individualDelays_il_6_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_4.txt',
#  'cbsstudy_individualDelays_il_6_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_5.txt',
#  'cbsstudy_individualDelays_il_6_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_6.txt',
#  'cbsstudy_individualDelays_il_6_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_7.txt',
#  'cbsstudy_individualDelays_il_6_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_8.txt',
#  'cbsstudy_individualDelays_il_6_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_6_s_9.txt',
#  'cbsstudy_individualDelays_il_6_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_1.txt',
#  'cbsstudy_individualDelays_il_7_s_10.txt',
#  'cbsstudy_individualDelays_il_7_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_11.txt',
#  'cbsstudy_individualDelays_il_7_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_12.txt',
#  'cbsstudy_individualDelays_il_7_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_13.txt',
#  'cbsstudy_individualDelays_il_7_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_14.txt',
#  'cbsstudy_individualDelays_il_7_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_15.txt',
#  'cbsstudy_individualDelays_il_7_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_16.txt',
#  'cbsstudy_individualDelays_il_7_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_17.txt',
#  'cbsstudy_individualDelays_il_7_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_18.txt',
#  'cbsstudy_individualDelays_il_7_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_19.txt',
#  'cbsstudy_individualDelays_il_7_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_2.txt',
#  'cbsstudy_individualDelays_il_7_s_20.txt',
#  'cbsstudy_individualDelays_il_7_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_3.txt',
#  'cbsstudy_individualDelays_il_7_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_4.txt',
#  'cbsstudy_individualDelays_il_7_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_5.txt',
#  'cbsstudy_individualDelays_il_7_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_6.txt',
#  'cbsstudy_individualDelays_il_7_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_7.txt',
#  'cbsstudy_individualDelays_il_7_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_8.txt',
#  'cbsstudy_individualDelays_il_7_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_7_s_9.txt',
#  'cbsstudy_individualDelays_il_7_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_1.txt',
#  'cbsstudy_individualDelays_il_8_s_10.txt',
#  'cbsstudy_individualDelays_il_8_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_11.txt',
#  'cbsstudy_individualDelays_il_8_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_12.txt',
#  'cbsstudy_individualDelays_il_8_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_13.txt',
#  'cbsstudy_individualDelays_il_8_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_14.txt',
#  'cbsstudy_individualDelays_il_8_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_15.txt',
#  'cbsstudy_individualDelays_il_8_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_16.txt',
#  'cbsstudy_individualDelays_il_8_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_17.txt',
#  'cbsstudy_individualDelays_il_8_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_18.txt',
#  'cbsstudy_individualDelays_il_8_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_19.txt',
#  'cbsstudy_individualDelays_il_8_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_2.txt',
#  'cbsstudy_individualDelays_il_8_s_20.txt',
#  'cbsstudy_individualDelays_il_8_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_3.txt',
#  'cbsstudy_individualDelays_il_8_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_4.txt',
#  'cbsstudy_individualDelays_il_8_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_5.txt',
#  'cbsstudy_individualDelays_il_8_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_6.txt',
#  'cbsstudy_individualDelays_il_8_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_7.txt',
#  'cbsstudy_individualDelays_il_8_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_8.txt',
#  'cbsstudy_individualDelays_il_8_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_8_s_9.txt',
#  'cbsstudy_individualDelays_il_8_s_9_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_1.txt',
#  'cbsstudy_individualDelays_il_9_s_10.txt',
#  'cbsstudy_individualDelays_il_9_s_10_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_11.txt',
#  'cbsstudy_individualDelays_il_9_s_11_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_12.txt',
#  'cbsstudy_individualDelays_il_9_s_12_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_13.txt',
#  'cbsstudy_individualDelays_il_9_s_13_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_14.txt',
#  'cbsstudy_individualDelays_il_9_s_14_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_15.txt',
#  'cbsstudy_individualDelays_il_9_s_15_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_16.txt',
#  'cbsstudy_individualDelays_il_9_s_16_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_17.txt',
#  'cbsstudy_individualDelays_il_9_s_17_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_18.txt',
#  'cbsstudy_individualDelays_il_9_s_18_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_19.txt',
#  'cbsstudy_individualDelays_il_9_s_19_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_1_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_2.txt',
#  'cbsstudy_individualDelays_il_9_s_20.txt',
#  'cbsstudy_individualDelays_il_9_s_20_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_2_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_3.txt',
#  'cbsstudy_individualDelays_il_9_s_3_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_4.txt',
#  'cbsstudy_individualDelays_il_9_s_4_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_5.txt',
#  'cbsstudy_individualDelays_il_9_s_5_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_6.txt',
#  'cbsstudy_individualDelays_il_9_s_6_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_7.txt',
#  'cbsstudy_individualDelays_il_9_s_7_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_8.txt',
#  'cbsstudy_individualDelays_il_9_s_8_withCT.txt',
#  'cbsstudy_individualDelays_il_9_s_9.txt',
#  'cbsstudy_individualDelays_il_9_s_9_withCT.txt']

# %% [markdown]
# # Read DYRECTsn Output from File and parse Idle Slopes

# %%
ncStageIdleSlopes = dict()
ncAggregateIdleSlopes = dict()
for file in files:
    # read file from the back to the front
    ctScheme = "NoPCTRes"
    if "withCT" in file:
        ctScheme = "PCTRes"
    if ctScheme not in ncStageIdleSlopes:
        ncStageIdleSlopes[ctScheme] = dict()
        ncAggregateIdleSlopes[ctScheme] = dict()
    il = int(file.split("il_")[1].split("_")[0])
    s = int(file.split("_s_")[1].split("_")[0].split(".")[0])
    with open(folder + "/" + file, "r") as f:
        lines = f.readlines()
        # read lines in reverse
        for line in lines[::-1]:
            if "Successfully" in line:
                split = line.strip().split(":")[-1].split("of")
                if split[0].strip() != split[1].strip():
                    print(f"Error: reservation unsuccessful for {file}")
                    break
                if (il, s) not in ncStageIdleSlopes[ctScheme]:
                    ncStageIdleSlopes[ctScheme][(il, s)] = dict()
            elif "Hop" in line:
                break ## reading reservation done
            elif "bit/s" in line:
                idleslope = int(ceil(float(line.split(":")[1].strip())))
                link = line.split(")")[0].replace("(","").strip().split(",")
                if "aggregate" in link[0]:
                    ncAggregateIdleSlopes[ctScheme][(il, s)] = idleslope
                    break 
                else:
                    fromSwitch = int(link[0].split("stage_")[1])
                    ncStageIdleSlopes[ctScheme][(il, s)][fromSwitch] = idleslope
# sort the results
print(ncStageIdleSlopes)
print(ncAggregateIdleSlopes)
# Out:
# Error: reservation unsuccessful for cbsstudy_individualDelays_il_12_s_20_withCT.txt
# Error: reservation unsuccessful for cbsstudy_individualDelays_il_13_s_14_withCT.txt
# Error: reservation unsuccessful for cbsstudy_individualDelays_il_13_s_15_withCT.txt
# Error: reservation unsuccessful for cbsstudy_individualDelays_il_13_s_16_withCT.txt
# Error: reservation unsuccessful for cbsstudy_individualDelays_il_13_s_17_withCT.txt
# Error: reservation unsuccessful for cbsstudy_individualDelays_il_13_s_18_withCT.txt
# Error: reservation unsuccessful for cbsstudy_individualDelays_il_13_s_19_withCT.txt
# Error: reservation unsuccessful for cbsstudy_individualDelays_il_13_s_20_withCT.txt
# {'NoPCTRes': {(10, 1): {0: 16717292}, (10, 10): {9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 11): {10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 12): {11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 13): {12: 65978477, 11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 14): {13: 67576660, 12: 65978477, 11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 15): {14: 69031429, 13: 67576660, 12: 65978477, 11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 16): {15: 70361258, 14: 69031429, 13: 67576660, 12: 65978477, 11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 17): {16: 71581581, 15: 70361258, 14: 69031429, 13: 67576660, 12: 65978477, 11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 18): {17: 72705388, 16: 71581581, 15: 70361258, 14: 69031429, 13: 67576660, 12: 65978477, 11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 19): {18: 73743695, 17: 72705388, 16: 71581581, 15: 70361258, 14: 69031429, 13: 67576660, 12: 65978477, 11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 2): {1: 25684353, 0: 16717292}, (10, 20): {19: 74705900, 18: 73743695, 17: 72705388, 16: 71581581, 15: 70361258, 14: 69031429, 13: 67576660, 12: 65978477, 11: 64214573, 10: 62257762, 9: 60074568, 8: 57623294, 7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 3): {2: 32908143, 1: 25684353, 0: 16717292}, (10, 4): {3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 5): {4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 6): {5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 7): {6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292}, (10, 8): {7: 54851333, 6: 51691349, 5: 48055737, 4: 43828374, 3: 38851984, 2: 32908143, 1: 25684353, 0: 16717292},
            for s in range(1, 10):
                if fromSwitch >= s:
                    continue
                elif ncStageIdleSlopes[ctScheme][(il, s)][fromSwitch] != idleslope:
                    # print(f"Error: {ctScheme} {fromSwitch} {il} {s} {ncStageIdleSlopes[ctScheme][(il, s)][fromSwitch]} != {idleslope}")
                    pass
                else:
                    print(f"{ctScheme} {fromSwitch} {il} {s} {ncStageIdleSlopes[ctScheme][(il, s)][fromSwitch]} == {idleslope}")

# %% [markdown]
# # Export to OMNET.ini Study

# %%
def writePCTGen(f, il, s, stageIdleSlopes):
    sToUs = 1000000
    for fromSwitch in stageIdleSlopes:
        prefix =f"**.ctSrc[{fromSwitch}].services[0].startTime = 0.1s - 1us + (500ns*ancestorIndex(2)) + ({fromSwitch}*8us) "
        totalBandwidth = 75000000
        linkrate = 100000000
        talkerInterval = 0.000125
        ctInterval = 0.1
        talkerSize = floor(((totalBandwidth / 8.0) * talkerInterval) / il)
        ctSize = floor(((totalBandwidth / 8.0) * talkerInterval) - (((totalBandwidth / 8.0) * talkerInterval) / il))
        delayAsStr = prefix
        for switch in range(0, fromSwitch):
            idleslope = stageIdleSlopes[switch]
            sendslope = linkrate - idleslope
            delay = ((ctSize * 8.0) * (sendslope/linkrate)) / idleslope
            delayAsStr += " + " + format(delay*sToUs, ".3f") + "us"
        transmissionDelay = ((talkerSize-12) * 8 / linkrate)
        ctDelay = ((ctSize-12) * 8 / linkrate)
        delayAsStr += f" + ({fromSwitch+1})*" + format(transmissionDelay*sToUs, ".3f") + "us"
        delayAsStr += f" + ({fromSwitch-1})*" + format(ctDelay*sToUs, ".3f") + "us"
        f.write(delayAsStr + "\n")

def writePCTGenAggregate(f, il, s, stageIdleSlopes):
    sToUs = 1000000
    prefix =f"**.aggregateCTSrc.services[*].startTime = 0.1s - 1us + ({s}*8us)"
    totalBandwidth = 75000000
    linkrate = 100000000
    talkerInterval = 0.000125
    ctInterval = 0.1
    talkerSize = floor(((totalBandwidth / 8.0) * talkerInterval) / il)
    ctSize = floor(((totalBandwidth / 8.0) * talkerInterval) - (((totalBandwidth / 8.0) * talkerInterval) / il))
    delayAsStr = prefix
    for switch in stageIdleSlopes:
        idleslope = stageIdleSlopes[switch]
        sendslope = linkrate - idleslope
        delay = ((ctSize * 8.0) * (sendslope/linkrate)) / idleslope
        delayAsStr += " + " + format(delay*sToUs, ".3f") + "us"
    transmissionDelay = ((talkerSize-12) * 8 / linkrate)
    ctDelay = ((ctSize-12) * 8 / linkrate)
    delayAsStr += f" + ({s+1})*" + format(transmissionDelay*sToUs, ".3f") + "us"
    delayAsStr += f" + ({s})*" + format(ctDelay*sToUs, ".3f") + "us"
    delayAsStr += " - second(((1522)*8)/100000000)"
    f.write(delayAsStr + "\n")

# %%
def setIdleSlopeStageSwitch(stage, maxstage, idleslope):
    return f"**.stageSwitch[{stage}].etherMAC[1].shaper.transmissionSelectionAlgorithm[7].staticIdleSlope = {idleslope}bps"

def setAggregateSwitch(idleslope):
    return f"**.aggregateSwitch.etherMAC[0].shaper.transmissionSelectionAlgorithm[7].staticIdleSlope = {idleslope}bps"

def writeConfig(ctScheme, il, s, stageIdleSlopes, aggregateIdleSlope, f):
    config = f"[Config NC_{ctScheme}_IL-{il}_S-{s}]\n"
    f.write(config)
    f.write("extends=NC\n")    
    # f.write("**.numInputLinks = ${IL=" + str(il) + "}\n")
    # f.write("**.numStages = ${S=" + str(s) + "}\n")
    for fromSwitch in ncStageIdleSlopes[ctScheme][(il, s)]:
        idleslope = stageIdleSlopes[fromSwitch]
        f.write(setIdleSlopeStageSwitch(fromSwitch, s-1, idleslope) + "\n")
    f.write(setAggregateSwitch(aggregateIdleSlope) + "\n")
    f.write("\n")

def writeNCPrioCTConfig(il, s, stageIdleSlopes, f):
    ctScheme = "PCTRes"
    config = f"[Config NC_PCT_IL-{il}_S-{s}]\n"
    f.write(config)
    f.write("extends=CrossTraffic\n")
    f.write("# register be ct but never actually send a message, stop when subscriber registers\n")
    f.write("**.ctSrc[*].services[2].stopTime = 0.12s\n")
    writePCTGen(f, il, s, stageIdleSlopes)
    writePCTGenAggregate(f, il, s, stageIdleSlopes)
    f.write("\n")

def writeStudies(f, il, s):
    f.write(f"[Config Study_NC_NoCT_IL-{il}_S-{s}]\n")
    f.write(f"extends=NC_PCTRes_IL-{il}_S-{s}\n")
    f.write("\n")
    f.write(f"[Config Study_NC_BECT_IL-{il}_S-{s}]\n")
    f.write(f"extends=NC_PCTRes_IL-{il}_S-{s},BECrossTraffic\n")
    f.write("\n")
    f.write(f"[Config Study_NC_PCT_IL-{il}_S-{s}]\n")
    f.write(f"extends=NC_PCTRes_IL-{il}_S-{s},NC_PCT_IL-{il}_S-{s}\n")
    f.write("\n")
    f.write(f"[Config Study_NC_NoCT_NoPCTRes_IL-{il}_S-{s}]\n")
    f.write(f"extends=NC_NoPCTRes_IL-{il}_S-{s}\n")
    f.write("\n")
    f.write(f"[Config Study_NC_BECT_NoPCTRes_IL-{il}_S-{s}]\n")
    f.write(f"extends=NC_NoPCTRes_IL-{il}_S-{s},BECrossTraffic\n")
    f.write("\n")

# %%
outfile = "../nc_config.ini"
with open(outfile, "w") as f:
    f.write("# This file is generated by the script\n")
    f.write("# All studies are to be executed only for the IL and S combination in their name.\n")
    f.write("[Config NC] ## defined in omnetpp.ini\n")
    f.write("\n")
    for ctScheme in ncStageIdleSlopes:
        for key in ncStageIdleSlopes[ctScheme]:
            il = key[0]
            s = key[1]
            writeConfig(ctScheme, il, s, ncStageIdleSlopes[ctScheme][key], ncAggregateIdleSlopes[ctScheme][key], f)
            if ctScheme == "PCTRes":
                writeNCPrioCTConfig(il, s, ncStageIdleSlopes[ctScheme][key], f)
    f.write("#################################################\n#################### STUDIES ####################\n#################################################\n")
    for ctScheme in ncStageIdleSlopes:
        for key in ncStageIdleSlopes[ctScheme]:
            il = key[0]
            s = key[1]
            writeStudies(f, il, s)
        break
